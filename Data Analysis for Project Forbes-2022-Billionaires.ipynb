# %%
import numpy  as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
sns.set_theme(rc={'figure.figsize':(8, 8)}, font_scale=1.3)
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"E:\AI from A to Z Course\Python for DA & AI\Session 04\Project 2\Forbes-2022-Billionaires-db.csv",
                 encoding="latin-1") #utf-8

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  \
# 0             Automotive       Tesla, SpaceX  United States       Texas
# 1             Technology              Amazon  United States  Washington
# 2       Fashion & Retail                LVMH         France         NaN
# 3             Technology           Microsoft  United States  Washington
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska
#
#       city countryOfCitizenship                       organization  selfMade  \
# 0   Austin        United States                              Tesla      True
# 1  Seattle        United States                             Amazon      True
# 2    Paris               France  LVMH MoÃ«t Hennessy Louis Vuitton     False
# 3   Medina        United States    Bill & Melinda Gates Foundation      True
# 4    Omaha        United States                 Berkshire Hathaway      True
#
#   gender   birthDate             title  philanthropyScore  \
# 0      M  1971-06-28               CEO                1.0
# 1      M  1964-01-12      Entrepreneur                1.0
# 2      M  1949-03-05  Chairman and CEO                NaN
# 3      M  1955-10-28         Cofounder                4.0
# 4      M  1930-08-30               CEO                5.0
#
#                   residenceMsa  numberOfSiblings  \
# 0                          NaN               NaN
# 1  Seattle-Tacoma-Bellevue, WA               NaN
# 2                          NaN               NaN
# 3  Seattle-Tacoma-Bellevue, WA               NaN
# 4                    Omaha, NE               NaN
#
#                                                  bio  \
# 0  Elon Musk is working to revolutionize transpor...
# 1  Jeff Bezos founded e-commerce giant Amazon in ...
# 2  Bernard Arnault oversees the LVMH empire of so...
# 3  Bill Gates turned his fortune from software fi...
# 4  Known as the "Oracle of Omaha," Warren Buffett...
#
#                                                about
# 0  Musk was accepted to a graduate program at Sta...
# 1  Growing up, Jeff Bezos worked summers on his g...
# 2  Arnault apparently wooed his wife, Helene Merc...
# 3  When Gates was a kid, he spent so much time re...
# 4  Buffett still lives in the same Omaha, Nebrask...

# %%
df.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state          city  \
# 2663  Manufacturing               Fiberglass   China   NaN     Tongxiang
# 2664     Technology               Navigation   China   NaN       Beijing
# 2665  Manufacturing                chemicals   China   NaN      Shanghai
# 2666         Energy  liquefied petroleum gas   China   NaN  Zhangjiagang
# 2667  Manufacturing                polyester   China   NaN       Jiaxing
#
#      countryOfCitizenship organization  selfMade gender   birthDate title  \
# 2663                China          NaN      True      M  1955-09-01   NaN
# 2664                China          NaN      True      M  1963-03-01   NaN
# 2665                China          NaN      True      M  1965-03-06   NaN
# 2666                China          NaN      True      F  1978-07-11   NaN
# 2667                China          NaN      True      M  1962-06-15   NaN
#
#       philanthropyScore residenceMsa  numberOfSiblings  \
# 2663                NaN          NaN               NaN
# 2664                NaN          NaN               NaN
# 2665                NaN          NaN               NaN
# 2666                NaN          NaN               NaN
# 2667                NaN          NaN               NaN
#
#                                                     bio about
# 2663  Zhang Yuqiang chairs Zhenshi Holding Group, a ...   NaN
# 2664  Zhou Ruxin chairs Beijing BDStar Navigation, a...   NaN
# 2665  Zhou Wen chairs Shanghai Pret Composites, a su...   NaN
# 2666  Zhou Yifeng chairs Shenzhen-listed Oriental En...   NaN
# 2667  Zhuang Kuilong chairs Xinfengming Group, a man...   NaN

# %%
df.sample(5)
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 431    431  Mahendra Choksi & family  80.0      5900.0  2022      4
# 454    438             David Steward  70.0      5800.0  2022      4
# 403    403               Hong Ra-hee  76.0      6300.0  2022      4
# 1574  1513                 Zhihan Xu  49.0      2000.0  2022      4
# 1165  1163              Yvonne Bauer  45.0      2700.0  2022      4
#
#                    category            source        country     state  \
# 431           Manufacturing            paints          India       NaN
# 454              Technology       IT provider  United States  Missouri
# 403              Technology           Samsung    South Korea       NaN
# 1574             Technology       electronics          China       NaN
# 1165  Media & Entertainment  magazines, media        Germany       NaN
#
#            city countryOfCitizenship organization  selfMade gender  \
# 431      Mumbai                India          NaN     False      M
# 454   St. Louis        United States          NaN      True      M
# 403       Seoul          South Korea          NaN     False      F
# 1574       Wuxi                China          NaN      True      M
# 1165    Hamburg              Germany          NaN     False      F
#
#        birthDate title  philanthropyScore   residenceMsa  numberOfSiblings  \
# 431   1941-04-19   NaN                NaN            NaN               NaN
# 454   1951-07-02   NaN                2.0  St. Louis, MO               NaN
# 403   1945-07-15   NaN                NaN            NaN               NaN
# 1574  1972-11-30   NaN                NaN            NaN               NaN
# 1165  1977-03-29   NaN                NaN            NaN               NaN
#
#                                                     bio  \
# 431   Mahendra Choksi is the son of one of four cofo...
# 454   David Steward is the founder and chairman of I...
# 403   Hong Ra-hee is the widow of Samsung Group Chai...
# 1574  Xu Zhihan chairs Maxscend Microelectronics, an...
# 1165  Yvonne Bauer runs Bauer Media Group, which has...
#
#                                                   about
# 431                                                 NaN
# 454   Steward's daughter was a producer of the 2016 ...
# 403                                                 NaN
# 1574                                                NaN
# 1165  In the digital sphere, Bauer Group runs over 4...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
#  15  birthDate             2569 non-null   object
#  16  title                 401 non-null    object
#  17  philanthropyScore     396 non-null    float64
#  18  residenceMsa          639 non-null    object
#  19  numberOfSiblings      127 non-null    float64
#  20  bio                   2668 non-null   object
#  21  about                 1562 non-null   object
# dtypes: bool(1), float64(4), int64(3), object(14)
# memory usage: 440.4+ KB

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.describe()
# Out:
#               rank          age     finalWorth    year   month  \
# count  2668.000000  2582.000000    2668.000000  2668.0  2668.0
# mean   1302.919040    64.210689    4762.350075  2022.0     4.0
# std     747.807782    13.401258   10540.482258     0.0     0.0
# min       1.000000    19.000000    1000.000000  2022.0     4.0
# 25%     665.000000    55.000000    1500.000000  2022.0     4.0
# 50%    1292.000000    64.000000    2400.000000  2022.0     4.0
# 75%    1929.000000    74.000000    4300.000000  2022.0     4.0
# max    2578.000000   100.000000  219000.000000  2022.0     4.0
#
#        philanthropyScore  numberOfSiblings
# count         396.000000        127.000000
# mean            1.856061          2.732283
# std             0.971486          1.891706
# min             1.000000          1.000000
# 25%             1.000000          2.000000
# 50%             2.000000          2.000000
# 75%             2.000000          3.000000
# max             5.000000         14.000000

# %%
df.describe(include='object')
# Out:
#        personName               category       source        country  \
# count        2668                   2668         2668           2655
# unique       2666                     18          914             73
# top         Li Li  Finance & Investments  real estate  United States
# freq            2                    392          151            748
#
#              state      city countryOfCitizenship    organization gender  \
# count          748      2624                 2668             352   2652
# unique          42       749                   75             316      2
# top     California  New York        United States  Meta Platforms      M
# freq           186       106                  735               4   2341
#
#          birthDate         title  residenceMsa  \
# count         2569           401           639
# unique        2044            94           109
# top     1965-01-01  Entrepreneur  New York, NY
# freq            19            73           119
#
#                                                       bio  \
# count                                                2668
# unique                                               2668
# top     Elon Musk is working to revolutionize transpor...
# freq                                                    1
#
#                                                     about
# count                                                1562
# unique                                               1548
# top     The family's Knauf Museum, on the premises of ...
# freq                                                    4

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# numberOfSiblings        2541
# organization            2316
# philanthropyScore       2272
# title                   2267
# residenceMsa            2029
# state                   1920
# about                   1106
# birthDate                 99
# age                       86
# city                      44
# gender                    16
# country                   13
# bio                        0
# rank                       0
# selfMade                   0
# personName                 0
# source                     0
# category                   0
# month                      0
# year                       0
# finalWorth                 0
# countryOfCitizenship       0
# dtype: int64

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}  -  {}%'.format(col, round(pct_missing*100)))
# Out:
# rank  -  0%
# personName  -  0%
# age  -  3%
# finalWorth  -  0%
# year  -  0%
# month  -  0%
# category  -  0%
# source  -  0%
# country  -  0%
# state  -  72%
# city  -  2%
# countryOfCitizenship  -  0%
# organization  -  87%
# selfMade  -  0%
# gender  -  1%
# birthDate  -  4%
# title  -  85%
# philanthropyScore  -  85%
# residenceMsa  -  76%
# numberOfSiblings  -  95%
# bio  -  0%
# about  -  41%

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    pct_missing =  round(pct_missing*100)
    if pct_missing >= 30 :
      df.drop([col],axis = 1,inplace = True)
      print('Droping {} Column as it contain - {}% null values'.format(col, pct_missing))
# Out:
# Droping state Column as it contain - 72% null values
# Droping organization Column as it contain - 87% null values
# Droping title Column as it contain - 85% null values
# Droping philanthropyScore Column as it contain - 85% null values
# Droping residenceMsa Column as it contain - 76% null values
# Droping numberOfSiblings Column as it contain - 95% null values
# Droping about Column as it contain - 41% null values

# %%
df.shape
# Out:
# (2668, 15)

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}  -  {}%'.format(col, round(pct_missing*100)))
# Out:
# rank  -  0%
# personName  -  0%
# age  -  3%
# finalWorth  -  0%
# year  -  0%
# month  -  0%
# category  -  0%
# source  -  0%
# country  -  0%
# city  -  2%
# countryOfCitizenship  -  0%
# selfMade  -  0%
# gender  -  1%
# birthDate  -  4%
# bio  -  0%

# %%
for column in df.columns:
    if df[column].dtype == 'object':  
        df[column] = df[column].fillna(df[column].mode()[0])
    elif df[column].dtype in ['int64', 'float64']:  
        df[column] = df[column].fillna(df[column].mean())

# %%
df.isnull().sum()
# Out:
# rank                    0
# personName              0
# age                     0
# finalWorth              0
# year                    0
# month                   0
# category                0
# source                  0
# country                 0
# city                    0
# countryOfCitizenship    0
# selfMade                0
# gender                  0
# birthDate               0
# bio                     0
# dtype: int64

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country     city  \
# 0             Automotive       Tesla, SpaceX  United States   Austin
# 1             Technology              Amazon  United States  Seattle
# 2       Fashion & Retail                LVMH         France    Paris
# 3             Technology           Microsoft  United States   Medina
# 4  Finance & Investments  Berkshire Hathaway  United States    Omaha
#
#   countryOfCitizenship  selfMade gender   birthDate  \
# 0        United States      True      M  1971-06-28
# 1        United States      True      M  1964-01-12
# 2               France     False      M  1949-03-05
# 3        United States      True      M  1955-10-28
# 4        United States      True      M  1930-08-30
#
#                                                  bio
# 0  Elon Musk is working to revolutionize transpor...
# 1  Jeff Bezos founded e-commerce giant Amazon in ...
# 2  Bernard Arnault oversees the LVMH empire of so...
# 3  Bill Gates turned his fortune from software fi...
# 4  Known as the "Oracle of Omaha," Warren Buffett...

# %%
columns_drop = 'source '.split()
columns_drop
# Out:
# ['source']

# %%
df.drop(columns_drop,axis=1,inplace=True)

# %%
df.shape
# Out:
# (2668, 14)

# %% [markdown]
# We start with 22 columns after droping columns that contain 30% null values or more and anthor columns that aren't important , we finally has 14 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2668 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   country               2668 non-null   object
#  8   city                  2668 non-null   object
#  9   countryOfCitizenship  2668 non-null   object
#  10  selfMade              2668 non-null   bool
#  11  gender                2668 non-null   object
#  12  birthDate             2668 non-null   object
#  13  bio                   2668 non-null   object
# dtypes: bool(1), float64(2), int64(3), object(8)
# memory usage: 273.7+ KB

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'country', 'city', 'countryOfCitizenship', 'selfMade', 'gender',
#        'birthDate', 'bio'],
#       dtype='object')

# %% [markdown]
# Top 10 Forbes-2022-Billionaires in the world

# %%
top_10_name= df['personName'].value_counts().head(10)
top_10_name
# Out:
# Li Li                              2
# Wang Yanqing & family              2
# Elon Musk                          1
# M.Satyanarayana Reddy              1
# Deepak Mehta                       1
# Mario Moretti Polegato & family    1
# Alberto Palatchi                   1
# Nelson Peltz                       1
# Jorge Perez                        1
# Alberto Prada                      1
# Name: personName, dtype: int64

# %%
top_10_name.index
# Out:
# Index(['Li Li', 'Wang Yanqing & family', 'Elon Musk', 'M.Satyanarayana Reddy',
#        'Deepak Mehta', 'Mario Moretti Polegato & family', 'Alberto Palatchi',
#        'Nelson Peltz', 'Jorge Perez', 'Alberto Prada'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_name.values, y=top_10_name.index, palette="coolwarm")
plt.title("Top 10 Forbes-2022-Billionaires in the world", size=16)
plt.xlabel("Names", size=14)
plt.ylabel("finalWorth", size=14)
plt.savefig('top_10_Forbes.png')
plt.show()

# %% [markdown]
# Gender of Forbes-2022-Billionaires in the world (Male or Female)

# %%
df['gender'] = df['gender'].str.strip() # حذف المسافات الزائدة

#df['gender_label'] = df['gender'].map({'M': "Male", 'F': "Female"})

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category        country     city countryOfCitizenship  \
# 0             Automotive  United States   Austin        United States
# 1             Technology  United States  Seattle        United States
# 2       Fashion & Retail         France    Paris               France
# 3             Technology  United States   Medina        United States
# 4  Finance & Investments  United States    Omaha        United States
#
#    selfMade gender   birthDate  \
# 0      True      M  1971-06-28
# 1      True      M  1964-01-12
# 2     False      M  1949-03-05
# 3      True      M  1955-10-28
# 4      True      M  1930-08-30
#
#                                                  bio gender_label
# 0  Elon Musk is working to revolutionize transpor...         Male
# 1  Jeff Bezos founded e-commerce giant Amazon in ...         Male
# 2  Bernard Arnault oversees the LVMH empire of so...         Male
# 3  Bill Gates turned his fortune from software fi...         Male
# 4  Known as the "Oracle of Omaha," Warren Buffett...         Male

# %%
sns.countplot(x = df['gender_label'],order = df['gender_label'].value_counts().index)
plt.title("Male or Female of Forbes-2022-Billionaires ", size=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.pie(df['gender_label'].value_counts(),labels=['Male','Female'],
        autopct ='%1.2f%%',shadow = True, explode = [0,0.1],colors = ['r','b'])
plt.title("Male or Female of Forbes-2022-Billionaires ", size=20)
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# **Insight:The chart clearly shows that the city  of Forbes-2022-Billionaires

# %% [markdown]
# Forbes-2022-Billionaires and their city

# %% [markdown]
# For City

# %%
df['city'].value_counts()
# Out:
# New York        150
# Beijing          83
# Hong Kong        68
# London           64
# Shanghai         61
#                ...
# Xinxiang          1
# Sioux Falls       1
# Scottsdale        1
# Newbury Park      1
# Pottsville        1
# Name: city, Length: 749, dtype: int64

# %%
# 1. ضبط الحجم ليكون متناسقاً (ليس ضخماً جداً)
sns.set_theme(rc={'figure.figsize':(12, 7)}, font_scale=1.1)

# 2. أخذ عينة محددة (أول 10 مدن مثلاً) لتظهر الأعمدة كبيرة
data_to_plot = df['city'].value_counts().head(10)

# 3. الرسم مع زيادة عرض العمود (width)
plt.bar(data_to_plot.index, data_to_plot.values, 
        facecolor='pink', edgecolor='blue', width=0.6) # تقليل الـ width يجعلها أعرض بصرياً بالنسبة للمساحة

plt.title("Top 10 Cities in Forbes 2022", size=20)
plt.xticks(rotation=45) # تدوير الأسماء لكي لا تتداخل
plt.ylabel("Number of Billionaires")

plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df, x='category', y='finalWorth', palette='viridis')
plt.title("Wealth Distribution by Industry Category", size=20)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.set_theme(rc={'figure.figsize':(15, 10)}, font_scale=1)
plt.title(" Top 10 Cities in Forbes 2022  ", size=20)
plt.bar(df['city'].value_counts().head(10).index,df['city'].value_counts().head(10),
        facecolor='r',edgecolor='b')
plt.show()

# %% [markdown]
# New York City has consistently been the primary hub for the world’s wealthiest individuals, maintaining the highest concentration of billionaires for decades."

# %%
sns.set_theme(rc={'figure.figsize':(20, 10)}, font_scale=1.4)


df.groupby('age')['finalWorth'].count().plot(color='b', ls='-', lw=8, alpha=0.85)

plt.title("Billionaire Distribution Growth by age", size=26)
plt.xlabel('age', color='k', size=20) 
plt.ylabel('Number of Billionaires', color='k', size=20) 

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')
